# %% [markdown]
# ## Carteira de Ações
#
# ### Modelo sugere uma carteira que atende as expectativas do usuário

# %%
import numpy as np
import pandas as pd
import pandas_datareader as web
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

start = datetime(2019, 1, 1)

symbols = ['^BVSP','PETR4.SA', 'PTBL3.SA', 'VALE3.SA']

df = pd.DataFrame()

for ticker in symbols: 
    r = web.DataReader(ticker, "yahoo", start)[['Close']].pct_change()
    df[ticker + 'Return'] = r['Close']

df = df.dropna()
df.head()
# Out:
#             ^BVSPReturn  PETR4.SAReturn  PTBL3.SAReturn  VALE3.SAReturn
# Date
# 2019-01-03     0.006065        0.024522        0.009259       -0.040908
# 2019-01-04     0.003025        0.002840       -0.018349        0.065102
# 2019-01-07    -0.001546        0.015777        0.016822       -0.005365
# 2019-01-08     0.003631       -0.005974        0.005515        0.009632
# 2019-01-09     0.017179        0.020833        0.001828        0.024423

# %%
sns.displot(df['^BVSPReturn'])

# %%
sns.set()
df['^BVSPReturn'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
((df / df.iloc[0]) * 100).plot()
# Out:
# <AxesSubplot:xlabel='Date'>
